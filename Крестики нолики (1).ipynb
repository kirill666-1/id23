# %%
def print_desk(l1,l2,l3):
    print(l1)
    print(l2)
    print(l3)
def search(x,l1,l2,l3,i):
    if x==0 or x==1 or x==2:
        if i%2==0:
            l1[x] = 'x'
        else:
            l1[x] = '0'
    if x==3 or x==4 or x==5:
        if i%2==0:
            l2[x%3] = 'x'
        else:
            l2[x%3] = '0'
    if x==6 or x==7 or x==8:
        if i%2==0:
            l3[x%3] = 'x'
        else:
            l3[x%3] = '0'
    return(l1,l2,l3)
print('Игра Крестики-нолики')
print('Введите число от 1 до 9, которое будет означать клетку игрового поля, куда вы ходите')
pole = [0,0,0,0,0,0,0,0,0]
l1 = ['-','-','-']
l2 = ['-','-','-']
l3 = ['-','-','-']
win = False
for i in range(9):
    if win:
        break
    else:
        print('Введите число от 1 до 9')
        turn = int(input())
        if pole[turn-1]==0:
            pole[turn-1] = 1
            l1,l2,l3 = search(turn-1,l1,l2,l3,i)
            print_desk(l1,l2,l3) 
        else:
            print('error u can not go there')
            break
        #Проверка на победу
        if l1==['x','x','x'] or l1==['0','0','0']:
            win =True
        if l2==['x','x','x'] or l2==['0','0','0']:
            win =True
        if l3==['x','x','x'] or l3==['0','0','0']:
            win =True
        if (l1[0]=='x' and l2[0]=='x' and l3[0]=='x') or (l1[1]=='x' and l2[1]=='x' and l3[1]=='x') or (l1[2]=='x' and l2[2]=='x' and l3[2]=='x'):
            win = True
        if (l1[0]=='0' and l2[0]=='0' and l3[0]=='0') or (l1[1]=='0' and l2[1]=='0' and l3[1]=='0') or (l1[2]=='0' and l2[2]=='0' and l3[2]=='0'):
            win = True
        if (l1[0]=='x' and l2[1]=='x' and l3[2]=='x') or (l1[2]=='x' and l2[1]=='x' and l3[0]=='x'):
            win = True
        if l1[0]=='y' and l2[1]=='y' and l3[2]=='y'or (l1[2]=='y' and l2[1]=='y' and l3[0]=='y'):
            win = True     
if i!=8:
    if i%2==0 :
        print('The winner is player 2')
    else:
        print('The winner is player 1')
else:
    print('Draw')
# Out:
# Игра Крестики-нолики
# Введите число от 1 до 9, которое будет означать клетку игрового поля, куда вы ходите
# Введите число от 1 до 9
# 5
# ['-', '-', '-']
# ['-', 'x', '-']
# ['-', '-', '-']
# Введите число от 1 до 9
# 9
# ['-', '-', '-']
# ['-', 'x', '-']
# ['-', '-', '0']
# Введите число от 1 до 9
# 1
# ['x', '-', '-']
# ['-', 'x', '-']
# ['-', '-', '0']
# Введите число от 1 до 9
# 3
# ['x', '-', '0']
# ['-', 'x', '-']
# ['-', '-', '0']
# Введите число от 1 до 9
# 2
# ['x', 'x', '0']
# ['-', 'x', '-']
# ['-', '-', '0']
# Введите число от 1 до 9
# 6
# ['x', 'x', '0']
# ['-', 'x', '0']
# ['-', '-', '0']
# The winner is player 2
